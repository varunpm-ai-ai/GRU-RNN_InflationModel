# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("../../datasets/IndiaDataset/india_inflation_dataset.csv")
print(df.head())
# Out:
#          Date       CPI  GDP_Growth  Unemployment_Rate  Crude_Oil_Prices  \
# 0  2007-01-31  5.745071    6.715575           5.086687         81.354829
# 1  2007-02-28  4.792604    7.121569           6.280750         56.167520
# 2  2007-03-31  5.971533    8.166102           7.006292         83.044089
# 3  2007-04-30  7.284545    8.107604           7.056377         90.334568
# 4  2007-05-31  4.648770    3.244661           6.459921         76.201524
#
#    Gold_Prices  Real_Estate_Index   Stock_Index  Money_Supply_M1  \
# 0  1687.656761         140.990332  40626.122513         6.859267
# 1  1396.791054         133.869505  37852.972294        11.609958
# 2  1519.224155         120.894456  40611.487515        13.557112
# 3  1407.544942         110.295948  42716.490145        12.156860
# 4  1413.100755         130.473350  40244.300352        12.988143
#
#    Money_Supply_M2  Industrial_Production  Retail_Sales  Exchange_Rate
# 0        11.451311               8.802381      6.649643      84.021741
# 1        16.124629               4.878678      7.710963      74.045481
# 2        10.062107               3.583186      6.415160      78.598790
# 3         9.602424               1.972571      7.384077      68.533635
# 4        10.551769               1.393721      4.212771      70.217818

# %%
print(df.shape)
print(" Columns : ",df.columns)
# Out:
# (200, 13)
#  Columns :  Index(['Date', 'CPI', 'GDP_Growth', 'Unemployment_Rate', 'Crude_Oil_Prices',
#        'Gold_Prices', 'Real_Estate_Index', 'Stock_Index', 'Money_Supply_M1',
#        'Money_Supply_M2', 'Industrial_Production', 'Retail_Sales',
#        'Exchange_Rate'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   200 non-null    object
#  1   CPI                    200 non-null    float64
#  2   GDP_Growth             200 non-null    float64
#  3   Unemployment_Rate      200 non-null    float64
#  4   Crude_Oil_Prices       200 non-null    float64
#  5   Gold_Prices            200 non-null    float64
#  6   Real_Estate_Index      200 non-null    float64
#  7   Stock_Index            200 non-null    float64
#  8   Money_Supply_M1        200 non-null    float64
#  9   Money_Supply_M2        200 non-null    float64
#  10  Industrial_Production  200 non-null    float64
#  11  Retail_Sales           200 non-null    float64
#  12  Exchange_Rate          200 non-null    float64
# dtypes: float64(12), object(1)
# memory usage: 20.4+ KB
# None

# %%
print(df.describe())
# Out:
#               CPI  GDP_Growth  Unemployment_Rate  Crude_Oil_Prices  \
# count  200.000000  200.000000         200.000000        200.000000
# mean     4.938844    6.171736           6.897214         70.134500
# std      1.396506    1.974008           1.192850         15.293615
# min      1.070382   -0.482535           4.034027         29.546700
# 25%      3.942308    4.788325           6.047346         59.402962
# 50%      4.993712    6.157679           6.906880         70.333937
# 75%      5.751279    7.374462           7.686506         80.277657
# max      9.080254   13.705463          10.694657        109.485731
#
#        Gold_Prices  Real_Estate_Index   Stock_Index  Money_Supply_M1  \
# count   200.000000         200.000000    200.000000       200.000000
# mean   1525.650289         122.004495  40026.872467        10.247891
# std     191.186639          15.454829   4930.998917         3.104900
# min    1015.224135          76.556169  27044.788539         1.235949
# 25%    1393.819836         112.438106  36649.113950         8.187686
# 50%    1526.107409         122.966328  39992.437772        10.229702
# 75%    1643.663242         133.101987  42804.954771        12.222905
# max    2005.386485         156.596286  52898.546688        17.805049
#
#        Money_Supply_M2  Industrial_Production  Retail_Sales  Exchange_Rate
# count       200.000000             200.000000    200.000000     200.000000
# mean         12.341424               5.037471      7.868279      74.966111
# std           2.853439               1.971387      1.947865       4.851027
# min           3.890303              -0.880777      1.960976      61.978931
# 25%          10.569409               3.770920      6.669438      71.679161
# 50%          12.218229               4.966839      7.898661      75.053341
# 75%          14.310082               6.332328      9.178737      78.405272
# max          21.579323              11.275497     13.519320      90.549593

# %%
print("Highest inflation year:")
print(df.loc[df['CPI'].idxmax()])
# Out:
# Highest inflation year:
# Date                       2021-12-31
# CPI                          9.080254
# GDP_Growth                   4.383403
# Unemployment_Rate            8.372505
# Crude_Oil_Prices            79.310081
# Gold_Prices               1652.082931
# Real_Estate_Index           103.44616
# Stock_Index              49130.048568
# Money_Supply_M1              7.569243
# Money_Supply_M2              9.922737
# Industrial_Production        5.814105
# Retail_Sales                   8.0136
# Exchange_Rate               76.301403
# Name: 179, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Year']
# Out:
# 0      2007
# 1      2007
# 2      2007
# 3      2007
# 4      2007
#        ...
# 195    2023
# 196    2023
# 197    2023
# 198    2023
# 199    2023
# Name: Year, Length: 200, dtype: int32

# %%
df1 = df[(df['Year'] >= 2006) & (df['Year'] <= 2015)]
df1
# Out:
#           Date       CPI  GDP_Growth  Unemployment_Rate  Crude_Oil_Prices  \
# 0   2007-01-31  5.745071    6.715575           5.086687         81.354829
# 1   2007-02-28  4.792604    7.121569           6.280750         56.167520
# 2   2007-03-31  5.971533    8.166102           7.006292         83.044089
# 3   2007-04-30  7.284545    8.107604           7.056377         90.334568
# 4   2007-05-31  4.648770    3.244661           6.459921         76.201524
# ..         ...       ...         ...                ...               ...
# 103 2015-08-31  3.796584    7.220741           7.675563         48.873081
# 104 2015-09-30  4.758071    5.958197           6.219229         46.650562
# 105 2015-10-31  5.606076    6.234655           6.415450         79.090149
# 106 2015-11-30  7.829279    8.555330           6.289127         50.793560
# 107 2015-12-31  5.261867    4.816857           5.963211         96.321913
#
#      Gold_Prices  Real_Estate_Index   Stock_Index  Money_Supply_M1  \
# 0    1687.656761         140.990332  40626.122513         6.859267
# 1    1396.791054         133.869505  37852.972294        11.609958
# 2    1519.224155         120.894456  40611.487515        13.557112
# 3    1407.544942         110.295948  42716.490145        12.156860
# 4    1413.100755         130.473350  40244.300352        12.988143
# ..           ...                ...           ...              ...
# 103  1755.690373         117.906156  36221.274203         9.989877
# 104  1538.219814         136.622742  42682.549218         9.489446
# 105  1509.287310         104.401411  35507.660091         8.640316
# 106  1228.028772         129.191609  40140.905787        12.089162
# 107  1649.250713         104.198767  39954.405017        12.865916
#
#      Money_Supply_M2  Industrial_Production  Retail_Sales  Exchange_Rate  Year
# 0          11.451311               8.802381      6.649643      84.021741  2007
# 1          16.124629               4.878678      7.710963      74.045481  2007
# 2          10.062107               3.583186      6.415160      78.598790  2007
# 3           9.602424               1.972571      7.384077      68.533635  2007
# 4          10.551769               1.393721      4.212771      70.217818  2007
# ..               ...                    ...           ...            ...   ...
# 103        15.329100               5.739284     10.250870      76.251001  2015
# 104        13.229456               4.785396      5.621176      84.978337  2015
# 105        11.276227               5.895434     11.285346      90.549593  2015
# 106        14.017721               1.858248      6.198759      78.033615  2015
# 107        17.699646               2.746465      9.276784      74.084017  2015
#
# [108 rows x 14 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(df1['Date'], df1['CPI'], marker='x',linewidth=2, color='blue')
plt.title('India Inflation Rate (2006–2015) for Customer Prise index')
plt.xlabel('Year')
plt.ylabel('Inflation Rate (%)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df1['Date'], df1['Gold_Prices'], marker='x',linewidth=2, color='orange')
plt.title('India Inflation Rate (2006–2015) for Customer Prise index')
plt.xlabel('Year')
plt.ylabel('Inflation Rate CPI (%)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df1['Date'], df1['Crude_Oil_Prices'], marker='x',linewidth=2, color='red')
plt.title('India Inflation Rate (2006–2015) for Crude_Oil_Prices')
plt.xlabel('Year')
plt.ylabel('Inflation Rate Crude_Oil_Prices (%)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df1['Date'], df1['Real_Estate_Index'], marker='x',linewidth=2, color='green')
plt.title('India Inflation Rate (2006–2015) for Real_Estate_Index')
plt.xlabel('Year')
plt.ylabel('Inflation Rate Real_Estate_Index (%)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df1['Date'], df1['Stock_Index'], marker='x',linewidth=2, color='purple')
plt.title('India Inflation Rate (2006–2015) for Stock_Index')
plt.xlabel('Year')
plt.ylabel('Inflation Rate Stock_Index (%)')
plt.grid(True)
plt.show()

# %%
df2 = df[(df['Year'] >= 2016) & (df['Year'] <= 2023)]
df2
# Out:
#           Date       CPI  GDP_Growth  Unemployment_Rate  Crude_Oil_Prices  \
# 108 2016-01-31  5.386326    7.094195           7.058226         38.771059
# 109 2016-02-29  4.888331    5.595615           6.002860         95.446846
# 110 2016-03-31  2.121843    5.564638           7.324548         73.165262
# 111 2016-04-30  4.960229    8.197554           6.939714         68.549303
# 112 2016-05-31  5.090345    7.650833           6.713262         61.826214
# ..         ...       ...         ...                ...               ...
# 195 2023-04-30  5.577976    5.061649           6.387980         85.797293
# 196 2023-05-31  3.674214    2.573731           6.676150         69.406673
# 197 2023-06-30  5.230588    8.707745           5.825484         80.222510
# 198 2023-07-31  5.087313    5.770920           6.466848         70.424776
# 199 2023-08-31  3.285545    8.475633           7.452761         70.446342
#
#      Gold_Prices  Real_Estate_Index   Stock_Index  Money_Supply_M1  \
# 108  1629.096836         110.643466  45429.477829        10.265221
# 109  1932.650945         148.710470  42373.491164        14.432590
# 110  1438.444353         117.139764  39874.865206         6.574933
# 111  1543.830066         123.261493  44088.831496         9.419022
# 112  1549.876737         133.051016  46951.037745         7.849533
# ..           ...                ...           ...              ...
# 195  1443.779941         126.607121  40923.401529         6.970808
# 196  1859.537305         119.705433  33264.368552        11.857463
# 197  1628.168572         128.287349  35141.929807        16.172486
# 198  1385.764202         123.358712  46002.069540        10.062381
# 199  1614.516556         140.462106  36715.528605         7.815991
#
#      Money_Supply_M2  Industrial_Production  Retail_Sales  Exchange_Rate  Year
# 108        11.602099               2.612150      7.342763      77.672528  2016
# 109         9.076412               5.285886      9.206375      79.438277  2016
# 110        15.321242               8.465030      6.911772      73.396662  2016
# 111        11.638857               9.462600      7.674414      83.976057  2016
# 112         5.481991               6.276102      8.081838      76.150354  2016
# ..               ...                    ...           ...            ...   ...
# 195         9.744092               7.140300      6.676036      67.751774  2023
# 196        11.042838               4.946957      8.851774      70.390701  2023
# 197         9.611922               3.236251      8.038296      69.980213  2023
# 198        15.228021               4.673866      6.717026      76.036337  2023
# 199        12.063935               3.510195      8.975745      75.346722  2023
#
# [92 rows x 14 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(df2['Date'], df2['CPI'], marker='x', linewidth=2, color='blue')
plt.title('India CPI Trend (2016–2023)')
plt.xlabel('Year')
plt.ylabel('CPI (%)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df2['Date'], df2['Gold_Prices'], marker='x', linewidth=2, color='orange')
plt.title('India Gold_Prices Trend (2016–2023)')
plt.xlabel('Year')
plt.ylabel('Gold_Prices (%)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df2['Date'], df2['Crude_Oil_Prices'], marker='x', linewidth=2, color='red')
plt.title('India Crude_Oil_Prices Trend (2016–2023)')
plt.xlabel('Year')
plt.ylabel('Crude_Oil_Prices (%)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df2['Date'], df2['Real_Estate_Index'], marker='x', linewidth=2, color='green')
plt.title('India Real_Estate_Index Trend (2016–2023)')
plt.xlabel('Year')
plt.ylabel('Real_Estate_Index (%)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df2['Date'], df2['Stock_Index'], marker='x', linewidth=2, color='purple')
plt.title('India Stock_Index Trend (2016–2023)')
plt.xlabel('Year')
plt.ylabel('Stock_Index (%)')
plt.show()

# %%
df1
# Out:
#           Date       CPI  GDP_Growth  Unemployment_Rate  Crude_Oil_Prices  \
# 0   2007-01-31  5.745071    6.715575           5.086687         81.354829
# 1   2007-02-28  4.792604    7.121569           6.280750         56.167520
# 2   2007-03-31  5.971533    8.166102           7.006292         83.044089
# 3   2007-04-30  7.284545    8.107604           7.056377         90.334568
# 4   2007-05-31  4.648770    3.244661           6.459921         76.201524
# ..         ...       ...         ...                ...               ...
# 103 2015-08-31  3.796584    7.220741           7.675563         48.873081
# 104 2015-09-30  4.758071    5.958197           6.219229         46.650562
# 105 2015-10-31  5.606076    6.234655           6.415450         79.090149
# 106 2015-11-30  7.829279    8.555330           6.289127         50.793560
# 107 2015-12-31  5.261867    4.816857           5.963211         96.321913
#
#      Gold_Prices  Real_Estate_Index   Stock_Index  Money_Supply_M1  \
# 0    1687.656761         140.990332  40626.122513         6.859267
# 1    1396.791054         133.869505  37852.972294        11.609958
# 2    1519.224155         120.894456  40611.487515        13.557112
# 3    1407.544942         110.295948  42716.490145        12.156860
# 4    1413.100755         130.473350  40244.300352        12.988143
# ..           ...                ...           ...              ...
# 103  1755.690373         117.906156  36221.274203         9.989877
# 104  1538.219814         136.622742  42682.549218         9.489446
# 105  1509.287310         104.401411  35507.660091         8.640316
# 106  1228.028772         129.191609  40140.905787        12.089162
# 107  1649.250713         104.198767  39954.405017        12.865916
#
#      Money_Supply_M2  Industrial_Production  Retail_Sales  Exchange_Rate  Year
# 0          11.451311               8.802381      6.649643      84.021741  2007
# 1          16.124629               4.878678      7.710963      74.045481  2007
# 2          10.062107               3.583186      6.415160      78.598790  2007
# 3           9.602424               1.972571      7.384077      68.533635  2007
# 4          10.551769               1.393721      4.212771      70.217818  2007
# ..               ...                    ...           ...            ...   ...
# 103        15.329100               5.739284     10.250870      76.251001  2015
# 104        13.229456               4.785396      5.621176      84.978337  2015
# 105        11.276227               5.895434     11.285346      90.549593  2015
# 106        14.017721               1.858248      6.198759      78.033615  2015
# 107        17.699646               2.746465      9.276784      74.084017  2015
#
# [108 rows x 14 columns]

# %%
df2
# Out:
#           Date       CPI  GDP_Growth  Unemployment_Rate  Crude_Oil_Prices  \
# 108 2016-01-31  5.386326    7.094195           7.058226         38.771059
# 109 2016-02-29  4.888331    5.595615           6.002860         95.446846
# 110 2016-03-31  2.121843    5.564638           7.324548         73.165262
# 111 2016-04-30  4.960229    8.197554           6.939714         68.549303
# 112 2016-05-31  5.090345    7.650833           6.713262         61.826214
# ..         ...       ...         ...                ...               ...
# 195 2023-04-30  5.577976    5.061649           6.387980         85.797293
# 196 2023-05-31  3.674214    2.573731           6.676150         69.406673
# 197 2023-06-30  5.230588    8.707745           5.825484         80.222510
# 198 2023-07-31  5.087313    5.770920           6.466848         70.424776
# 199 2023-08-31  3.285545    8.475633           7.452761         70.446342
#
#      Gold_Prices  Real_Estate_Index   Stock_Index  Money_Supply_M1  \
# 108  1629.096836         110.643466  45429.477829        10.265221
# 109  1932.650945         148.710470  42373.491164        14.432590
# 110  1438.444353         117.139764  39874.865206         6.574933
# 111  1543.830066         123.261493  44088.831496         9.419022
# 112  1549.876737         133.051016  46951.037745         7.849533
# ..           ...                ...           ...              ...
# 195  1443.779941         126.607121  40923.401529         6.970808
# 196  1859.537305         119.705433  33264.368552        11.857463
# 197  1628.168572         128.287349  35141.929807        16.172486
# 198  1385.764202         123.358712  46002.069540        10.062381
# 199  1614.516556         140.462106  36715.528605         7.815991
#
#      Money_Supply_M2  Industrial_Production  Retail_Sales  Exchange_Rate  Year
# 108        11.602099               2.612150      7.342763      77.672528  2016
# 109         9.076412               5.285886      9.206375      79.438277  2016
# 110        15.321242               8.465030      6.911772      73.396662  2016
# 111        11.638857               9.462600      7.674414      83.976057  2016
# 112         5.481991               6.276102      8.081838      76.150354  2016
# ..               ...                    ...           ...            ...   ...
# 195         9.744092               7.140300      6.676036      67.751774  2023
# 196        11.042838               4.946957      8.851774      70.390701  2023
# 197         9.611922               3.236251      8.038296      69.980213  2023
# 198        15.228021               4.673866      6.717026      76.036337  2023
# 199        12.063935               3.510195      8.975745      75.346722  2023
#
# [92 rows x 14 columns]

# %%
df4 = df[(df['Year'] >= 2006) & (df['Year'] <= 2023)]
df4
# Out:
#           Date       CPI  GDP_Growth  Unemployment_Rate  Crude_Oil_Prices  \
# 0   2007-01-31  5.745071    6.715575           5.086687         81.354829
# 1   2007-02-28  4.792604    7.121569           6.280750         56.167520
# 2   2007-03-31  5.971533    8.166102           7.006292         83.044089
# 3   2007-04-30  7.284545    8.107604           7.056377         90.334568
# 4   2007-05-31  4.648770    3.244661           6.459921         76.201524
# ..         ...       ...         ...                ...               ...
# 195 2023-04-30  5.577976    5.061649           6.387980         85.797293
# 196 2023-05-31  3.674214    2.573731           6.676150         69.406673
# 197 2023-06-30  5.230588    8.707745           5.825484         80.222510
# 198 2023-07-31  5.087313    5.770920           6.466848         70.424776
# 199 2023-08-31  3.285545    8.475633           7.452761         70.446342
#
#      Gold_Prices  Real_Estate_Index   Stock_Index  Money_Supply_M1  \
# 0    1687.656761         140.990332  40626.122513         6.859267
# 1    1396.791054         133.869505  37852.972294        11.609958
# 2    1519.224155         120.894456  40611.487515        13.557112
# 3    1407.544942         110.295948  42716.490145        12.156860
# 4    1413.100755         130.473350  40244.300352        12.988143
# ..           ...                ...           ...              ...
# 195  1443.779941         126.607121  40923.401529         6.970808
# 196  1859.537305         119.705433  33264.368552        11.857463
# 197  1628.168572         128.287349  35141.929807        16.172486
# 198  1385.764202         123.358712  46002.069540        10.062381
# 199  1614.516556         140.462106  36715.528605         7.815991
#
#      Money_Supply_M2  Industrial_Production  Retail_Sales  Exchange_Rate  Year
# 0          11.451311               8.802381      6.649643      84.021741  2007
# 1          16.124629               4.878678      7.710963      74.045481  2007
# 2          10.062107               3.583186      6.415160      78.598790  2007
# 3           9.602424               1.972571      7.384077      68.533635  2007
# 4          10.551769               1.393721      4.212771      70.217818  2007
# ..               ...                    ...           ...            ...   ...
# 195         9.744092               7.140300      6.676036      67.751774  2023
# 196        11.042838               4.946957      8.851774      70.390701  2023
# 197         9.611922               3.236251      8.038296      69.980213  2023
# 198        15.228021               4.673866      6.717026      76.036337  2023
# 199        12.063935               3.510195      8.975745      75.346722  2023
#
# [200 rows x 14 columns]

# %%
# Feature engineering
df_yearly = df4.groupby('Year').mean().reset_index()

df_yearly['CPI_lag1'] = df_yearly['CPI'].shift(1)
lag_cols = ['GDP_Growth', 'Unemployment_Rate', 'Crude_Oil_Prices', 
            'Gold_Prices', 'Real_Estate_Index', 'Stock_Index',
            'Money_Supply_M1', 'Money_Supply_M2', 'Industrial_Production', 
            'Retail_Sales', 'Exchange_Rate']

for col in lag_cols:
    df_yearly[f'{col}_lag1'] = df_yearly[col].shift(1)

df_yearly = df_yearly.dropna().reset_index(drop=True)
df_yearly
# Out:
#     Year                Date       CPI  GDP_Growth  Unemployment_Rate  \
# 0   2008 2008-07-15 20:00:00  4.113152    6.026150           7.677973
# 1   2009 2009-07-15 22:00:00  4.709997    6.204296           6.983692
# 2   2010 2010-07-15 22:00:00  4.501134    5.358729           6.547631
# 3   2011 2011-07-15 22:00:00  5.071874    6.792688           6.462077
# 4   2012 2012-07-15 20:00:00  5.218608    4.857653           6.886933
# 5   2013 2013-07-15 22:00:00  4.840034    6.176862           7.384744
# 6   2014 2014-07-15 22:00:00  4.762224    5.916498           7.141215
# 7   2015 2015-07-15 22:00:00  4.956278    6.566733           6.591984
# 8   2016 2016-07-15 20:00:00  5.195231    6.792853           6.884398
# 9   2017 2017-07-15 22:00:00  4.902143    6.339809           6.296681
# 10  2018 2018-07-15 22:00:00  4.828861    5.681420           6.898026
# 11  2019 2019-07-15 22:00:00  4.878889    5.572669           6.815149
# 12  2020 2020-07-15 20:00:00  5.756273    6.343160           6.971051
# 13  2021 2021-07-15 22:00:00  5.323190    7.013432           6.887029
# 14  2022 2022-07-15 22:00:00  4.764910    5.581241           7.151573
# 15  2023 2023-05-15 21:00:00  4.570992    6.496376           7.003680
#
#     Crude_Oil_Prices  Gold_Prices  Real_Estate_Index   Stock_Index  \
# 0          77.722432  1605.373013         125.444392  40922.672245
# 1          67.127164  1458.785195         122.654857  41731.532497
# 2          63.265379  1576.848263         120.791986  39388.849564
# 3          75.926856  1479.563359         124.349761  39821.441176
# 4          65.698917  1555.731634         115.031457  40080.807834
# 5          69.383682  1551.335229         120.899784  41744.814789
# 6          70.809673  1667.453145         123.685416  38748.018346
# 7          67.189214  1521.260552         118.776782  40111.767942
# 8          70.615859  1587.880599         128.494616  40347.102296
# 9          65.306272  1529.930773         123.539537  40061.532131
# 10         70.508511  1430.019405         126.376595  40727.681771
# 11         65.863693  1501.584360         114.498404  36422.659406
# 12         75.890515  1619.488071         125.485362  39307.487673
# 13         71.948621  1368.812355         117.014727  40032.619870
# 14         72.091241  1489.798886         117.520991  41961.288018
# 15         69.375525  1505.701281         121.287754  40121.287896
#
#     Money_Supply_M1  ...  Unemployment_Rate_lag1  Crude_Oil_Prices_lag1  \
# 0         11.418441  ...                6.704291              73.309949
# 1          9.739941  ...                7.677973              77.722432
# 2         10.777783  ...                6.983692              67.127164
# 3         12.003805  ...                6.547631              63.265379
# 4          9.871475  ...                6.462077              75.926856
# 5         10.098641  ...                6.886933              65.698917
# 6         10.722469  ...                7.384744              69.383682
# 7         11.330085  ...                7.141215              70.809673
# 8         10.104242  ...                6.591984              67.189214
# 9         10.381390  ...                6.884398              70.615859
# 10         9.250611  ...                6.296681              65.306272
# 11         9.823795  ...                6.898026              70.508511
# 12        10.015411  ...                6.815149              65.863693
# 13         8.705226  ...                6.971051              75.890515
# 14         9.147866  ...                6.887029              71.948621
# 15         9.976477  ...                7.151573              72.091241
#
#     Gold_Prices_lag1  Real_Estate_Index_lag1  Stock_Index_lag1  \
# 0        1479.839125              127.985085      38956.740287
# 1        1605.373013              125.444392      40922.672245
# 2        1458.785195              122.654857      41731.532497
# 3        1576.848263              120.791986      39388.849564
# 4        1479.563359              124.349761      39821.441176
# 5        1555.731634              115.031457      40080.807834
# 6        1551.335229              120.899784      41744.814789
# 7        1667.453145              123.685416      38748.018346
# 8        1521.260552              118.776782      40111.767942
# 9        1587.880599              128.494616      40347.102296
# 10       1529.930773              123.539537      40061.532131
# 11       1430.019405              126.376595      40727.681771
# 12       1501.584360              114.498404      36422.659406
# 13       1619.488071              125.485362      39307.487673
# 14       1368.812355              117.014727      40032.619870
# 15       1489.798886              117.520991      41961.288018
#
#     Money_Supply_M1_lag1  Money_Supply_M2_lag1  Industrial_Production_lag1  \
# 0              10.756022             11.568456                    4.330761
# 1              11.418441             12.753257                    4.391799
# 2               9.739941             12.998508                    5.463691
# 3              10.777783             12.609285                    4.298156
# 4              12.003805             13.546519                    5.712108
# 5               9.871475             11.755254                    4.783358
# 6              10.098641             12.771061                    5.111757
# 7              10.722469             12.367995                    4.821376
# 8              11.330085             13.085167                    5.192327
# 9              10.104242             11.681218                    4.943189
# 10             10.381390             12.915766                    4.766663
# 11              9.250611             12.089782                    5.386276
# 12              9.823795             11.838183                    5.063770
# 13             10.015411             13.375982                    5.662490
# 14              8.705226             11.538070                    5.123542
# 15              9.147866             10.807228                    5.322838
#
#     Retail_Sales_lag1  Exchange_Rate_lag1
# 0            7.135041           75.598321
# 1            7.407256           75.472087
# 2            8.759515           74.658402
# 3            7.483765           74.972747
# 4            7.585435           74.093737
# 5            8.443461           75.289290
# 6            7.573995           73.189345
# 7            7.940998           76.267187
# 8            7.797319           77.673581
# 9            7.142949           76.364692
# 10           8.884970           76.547551
# 11           7.985703           75.239022
# 12           7.491916           75.154756
# 13           8.069475           72.615050
# 14           8.472919           75.334917
# 15           7.549882           73.184851
#
# [16 rows x 26 columns]

# %%
# Creating sequence for GRU RNN Model
def create_sequences(df, feature_cols, target_col, n_steps):
    X, y = [], []
    data = df[feature_cols + [target_col]].values
    for i in range(n_steps, len(df)):
        X.append(data[i-n_steps:i, :-1])  
        y.append(data[i, -1])            
    return np.array(X), np.array(y)


feature_cols = ['GDP_Growth', 'Unemployment_Rate', 'Crude_Oil_Prices',
                'Gold_Prices', 'Real_Estate_Index', 'Stock_Index',
                'Money_Supply_M1', 'Money_Supply_M2', 'Industrial_Production',
                'Retail_Sales', 'Exchange_Rate', 'CPI_lag1']

target_col = 'CPI'
n_steps = 4
X, y = create_sequences(df_yearly, feature_cols, target_col, n_steps)
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (12, 4, 12)
# y shape: (12,)

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
from sklearn.preprocessing import StandardScaler

scaler_y = StandardScaler()
y_train_s = scaler_y.fit_transform(y_train.reshape(-1,1)).flatten()
y_test_s  = scaler_y.transform(y_test.reshape(-1,1)).flatten()

# %%
Sequential = tf.keras.models.Sequential
GRU = tf.keras.layers.GRU
Dense = tf.keras.layers.Dense
Dropout = tf.keras.layers.Dropout
Adam = tf.keras.optimizers.Adam
l2 = tf.keras.regularizers.l2

model = Sequential([
    GRU(16, activation='tanh', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    GRU(8, activation='tanh'),
    Dropout(0.2),
    Dense(16, activation='relu', kernel_regularizer=l2(1e-4)),
    Dense(1)
])

model.compile(optimizer=Adam(learning_rate=1e-3), loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
model.summary()
# Out:
# c:\Web development\GRU-RNN_InflationModel\.venv\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_2 (GRU)                     │ (None, 4, 16)          │         1,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 8)              │           624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,225 (8.69 KB)
#  Trainable params: 2,225 (8.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# from tensorflow.keras.callbacks import EarlyStopping
EarlyStopping = tf.keras.callbacks.EarlyStopping
ReduceLROnPlateau = tf.keras.callbacks.ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

history = model.fit(
    X_train, y_train_s,
    epochs=500,
    batch_size=4,
    validation_data=(X_test, y_test_s),
    callbacks=[early_stop, reduce_lr],
    verbose=2
)
# Out:
# Epoch 1/500
# 3/3 - 16s - 5s/step - loss: 1.4870 - root_mean_squared_error: 1.2190 - val_loss: 1.9183 - val_root_mean_squared_error: 1.3847 - learning_rate: 1.0000e-03
# Epoch 2/500
# 3/3 - 1s - 184ms/step - loss: 1.1021 - root_mean_squared_error: 1.0494 - val_loss: 1.8379 - val_root_mean_squared_error: 1.3553 - learning_rate: 1.0000e-03
# Epoch 3/500
# 3/3 - 0s - 164ms/step - loss: 1.0608 - root_mean_squared_error: 1.0295 - val_loss: 1.7914 - val_root_mean_squared_error: 1.3381 - learning_rate: 1.0000e-03
# Epoch 4/500
# 3/3 - 0s - 130ms/step - loss: 0.8716 - root_mean_squared_error: 0.9330 - val_loss: 1.7583 - val_root_mean_squared_error: 1.3256 - learning_rate: 1.0000e-03
# Epoch 5/500
# 3/3 - 0s - 142ms/step - loss: 0.8774 - root_mean_squared_error: 0.9362 - val_loss: 1.7325 - val_root_mean_squared_error: 1.3159 - learning_rate: 1.0000e-03
# Epoch 6/500
# 3/3 - 0s - 143ms/step - loss: 1.0880 - root_mean_squared_error: 1.0426 - val_loss: 1.7049 - val_root_mean_squared_error: 1.3053 - learning_rate: 1.0000e-03
# Epoch 7/500
# 3/3 - 0s - 116ms/step - loss: 1.0032 - root_mean_squared_error: 1.0011 - val_loss: 1.6726 - val_root_mean_squared_error: 1.2929 - learning_rate: 1.0000e-03
# Epoch 8/500
# 3/3 - 0s - 133ms/step - loss: 1.0928 - root_mean_squared_error: 1.0449 - val_loss: 1.6460 - val_root_mean_squared_error: 1.2826 - learning_rate: 1.0000e-03
# Epoch 9/500
# 3/3 - 1s - 180ms/step - loss: 1.2345 - root_mean_squared_error: 1.1106 - val_loss: 1.6240 - val_root_mean_squared_error: 1.2740 - learning_rate: 1.0000e-03
# Epoch 10/500
# 3/3 - 0s - 156ms/step - loss: 1.2002 - root_mean_squared_error: 1.0951 - val_loss: 1.5993 - val_root_mean_squared_error: 1.2642 - learning_rate: 1.0000e-03
# Epoch 11/500
# 3/3 - 1s - 213ms/step - loss: 1.0194 - root_mean_squared_error: 1.0092 - val_loss: 1.5912 - val_root_mean_squared_error: 1.2610 - learning_rate: 1.0000e-03
# Epoch 12/500
# 3/3 - 0s - 119ms/step - loss: 1.0324 - root_mean_squared_error: 1.0156 - val_loss: 1.5811 - val_root_mean_squared_error: 1.2570 - learning_rate: 1.0000e-03
# Epoch 13/500
# 3/3 - 0s - 101ms/step - loss: 1.0824 - root_mean_squared_error: 1.0399 - val_loss: 1.5722 - val_root_mean_squared_error: 1.2535 - learning_rate: 1.0000e-03
# Epoch 14/500
# 3/3 - 0s - 114ms/step - loss: 1.0733 - root_mean_squared_error: 1.0355 - val_loss: 1.5605 - val_root_mean_squared_error: 1.2488 - learning_rate: 1.0000e-03
# Epoch 15/500
# 3/3 - 0s - 120ms/step - loss: 0.9191 - root_mean_squared_error: 0.9582 - val_loss: 1.5517 - val_root_mean_squared_error: 1.2453 - learning_rate: 1.0000e-03
# Epoch 16/500
# 3/3 - 0s - 133ms/step - loss: 0.9521 - root_mean_squared_error: 0.9752 - val_loss: 1.5433 - val_root_mean_squared_error: 1.2419 - learning_rate: 1.0000e-03
# Epoch 17/500
# 3/3 - 0s - 124ms/step - loss: 1.0685 - root_mean_squared_error: 1.0332 - val_loss: 1.5310 - val_root_mean_squared_error: 1.2370 - learning_rate: 1.0000e-03
# Epoch 18/500
# 3/3 - 0s - 111ms/step - loss: 1.0255 - root_mean_squared_error: 1.0122 - val_loss: 1.5206 - val_root_mean_squared_error: 1.2327 - learning_rate: 1.0000e-03
# Epoch 19/500
# 3/3 - 0s - 117ms/step - loss: 1.0261 - root_mean_squared_error: 1.0125 - val_loss: 1.5104 - val_root_mean_squared_error: 1.2286 - learning_rate: 1.0000e-03
# Epoch 20/500
# 3/3 - 0s - 99ms/step - loss: 1.0647 - root_mean_squared_error: 1.0313 - val_loss: 1.5053 - val_root_mean_squared_error: 1.2265 - learning_rate: 1.0000e-03
# Epoch 21/500
# 3/3 - 0s - 97ms/step - loss: 1.0128 - root_mean_squared_error: 1.0059 - val_loss: 1.5137 - val_root_mean_squared_error: 1.2299 - learning_rate: 1.0000e-03
# Epoch 22/500
# 3/3 - 0s - 140ms/step - loss: 1.0214 - root_mean_squared_error: 1.0101 - val_loss: 1.5172 - val_root_mean_squared_error: 1.2313 - learning_rate: 1.0000e-03
# Epoch 23/500
# 3/3 - 0s - 116ms/step - loss: 0.8362 - root_mean_squared_error: 0.9139 - val_loss: 1.5211 - val_root_mean_squared_error: 1.2329 - learning_rate: 1.0000e-03
# Epoch 24/500
# 3/3 - 1s - 188ms/step - loss: 1.1801 - root_mean_squared_error: 1.0859 - val_loss: 1.5268 - val_root_mean_squared_error: 1.2352 - learning_rate: 1.0000e-03
# Epoch 25/500
# 3/3 - 0s - 119ms/step - loss: 1.0649 - root_mean_squared_error: 1.0315 - val_loss: 1.5326 - val_root_mean_squared_error: 1.2376 - learning_rate: 1.0000e-03
# Epoch 26/500
# 3/3 - 0s - 99ms/step - loss: 0.9073 - root_mean_squared_error: 0.9520 - val_loss: 1.5341 - val_root_mean_squared_error: 1.2382 - learning_rate: 1.0000e-03
# Epoch 27/500
# 3/3 - 0s - 117ms/step - loss: 1.0771 - root_mean_squared_error: 1.0374 - val_loss: 1.5267 - val_root_mean_squared_error: 1.2352 - learning_rate: 1.0000e-03
# Epoch 28/500
# 3/3 - 0s - 118ms/step - loss: 1.0543 - root_mean_squared_error: 1.0263 - val_loss: 1.5155 - val_root_mean_squared_error: 1.2307 - learning_rate: 1.0000e-03
# Epoch 29/500
# 3/3 - 1s - 306ms/step - loss: 0.9760 - root_mean_squared_error: 0.9874 - val_loss: 1.5056 - val_root_mean_squared_error: 1.2266 - learning_rate: 1.0000e-03
# Epoch 30/500
# 3/3 - 1s - 225ms/step - loss: 0.8341 - root_mean_squared_error: 0.9128 - val_loss: 1.5006 - val_root_mean_squared_error: 1.2246 - learning_rate: 1.0000e-03
# Epoch 31/500
# 3/3 - 1s - 176ms/step - loss: 1.0639 - root_mean_squared_error: 1.0310 - val_loss: 1.4998 - val_root_mean_squared_error: 1.2243 - learning_rate: 1.0000e-03
# Epoch 32/500
# 3/3 - 0s - 137ms/step - loss: 1.0065 - root_mean_squared_error: 1.0027 - val_loss: 1.4940 - val_root_mean_squared_error: 1.2219 - learning_rate: 1.0000e-03
# Epoch 33/500
# 3/3 - 1s - 210ms/step - loss: 1.0583 - root_mean_squared_error: 1.0283 - val_loss: 1.4887 - val_root_mean_squared_error: 1.2197 - learning_rate: 1.0000e-03
# Epoch 34/500
# 3/3 - 1s - 239ms/step - loss: 0.9198 - root_mean_squared_error: 0.9586 - val_loss: 1.4851 - val_root_mean_squared_error: 1.2182 - learning_rate: 1.0000e-03
# Epoch 35/500
# 3/3 - 1s - 231ms/step - loss: 0.9994 - root_mean_squared_error: 0.9992 - val_loss: 1.4762 - val_root_mean_squared_error: 1.2146 - learning_rate: 1.0000e-03
# Epoch 36/500
# 3/3 - 1s - 203ms/step - loss: 0.9765 - root_mean_squared_error: 0.9877 - val_loss: 1.4686 - val_root_mean_squared_error: 1.2115 - learning_rate: 1.0000e-03
# Epoch 37/500
# 3/3 - 1s - 190ms/step - loss: 1.0722 - root_mean_squared_error: 1.0350 - val_loss: 1.4581 - val_root_mean_squared_error: 1.2071 - learning_rate: 1.0000e-03
# Epoch 38/500
# 3/3 - 1s - 240ms/step - loss: 1.0283 - root_mean_squared_error: 1.0136 - val_loss: 1.4468 - val_root_mean_squared_error: 1.2024 - learning_rate: 1.0000e-03
# Epoch 39/500
# 3/3 - 1s - 220ms/step - loss: 0.9847 - root_mean_squared_error: 0.9918 - val_loss: 1.4409 - val_root_mean_squared_error: 1.2000 - learning_rate: 1.0000e-03
# Epoch 40/500
# 3/3 - 0s - 158ms/step - loss: 1.0019 - root_mean_squared_error: 1.0004 - val_loss: 1.4374 - val_root_mean_squared_error: 1.1985 - learning_rate: 1.0000e-03
# Epoch 41/500
# 3/3 - 1s - 217ms/step - loss: 1.0650 - root_mean_squared_error: 1.0315 - val_loss: 1.4315 - val_root_mean_squared_error: 1.1960 - learning_rate: 1.0000e-03
# Epoch 42/500
# 3/3 - 0s - 119ms/step - loss: 0.9495 - root_mean_squared_error: 0.9739 - val_loss: 1.4220 - val_root_mean_squared_error: 1.1921 - learning_rate: 1.0000e-03
# Epoch 43/500
# 3/3 - 1s - 186ms/step - loss: 1.0810 - root_mean_squared_error: 1.0393 - val_loss: 1.4132 - val_root_mean_squared_error: 1.1884 - learning_rate: 1.0000e-03
# Epoch 44/500
# 3/3 - 1s - 183ms/step - loss: 1.0478 - root_mean_squared_error: 1.0231 - val_loss: 1.4030 - val_root_mean_squared_error: 1.1841 - learning_rate: 1.0000e-03
# Epoch 45/500
# 3/3 - 1s - 249ms/step - loss: 0.9564 - root_mean_squared_error: 0.9775 - val_loss: 1.4030 - val_root_mean_squared_error: 1.1841 - learning_rate: 1.0000e-03
# Epoch 46/500
# 3/3 - 1s - 170ms/step - loss: 1.0827 - root_mean_squared_error: 1.0401 - val_loss: 1.4024 - val_root_mean_squared_error: 1.1838 - learning_rate: 1.0000e-03
# Epoch 47/500
# 3/3 - 0s - 104ms/step - loss: 1.1332 - root_mean_squared_error: 1.0641 - val_loss: 1.4039 - val_root_mean_squared_error: 1.1844 - learning_rate: 1.0000e-03
# Epoch 48/500
# 3/3 - 1s - 215ms/step - loss: 0.9790 - root_mean_squared_error: 0.9890 - val_loss: 1.4033 - val_root_mean_squared_error: 1.1842 - learning_rate: 1.0000e-03
# Epoch 49/500
# 3/3 - 0s - 154ms/step - loss: 1.0958 - root_mean_squared_error: 1.0464 - val_loss: 1.4012 - val_root_mean_squared_error: 1.1833 - learning_rate: 1.0000e-03
# Epoch 50/500
# 3/3 - 0s - 144ms/step - loss: 0.8754 - root_mean_squared_error: 0.9351 - val_loss: 1.4003 - val_root_mean_squared_error: 1.1829 - learning_rate: 1.0000e-03
# Epoch 51/500
# 3/3 - 1s - 263ms/step - loss: 0.9303 - root_mean_squared_error: 0.9640 - val_loss: 1.3977 - val_root_mean_squared_error: 1.1818 - learning_rate: 1.0000e-03
# Epoch 52/500
# 3/3 - 0s - 158ms/step - loss: 1.0009 - root_mean_squared_error: 1.0000 - val_loss: 1.3980 - val_root_mean_squared_error: 1.1820 - learning_rate: 1.0000e-03
# Epoch 53/500
# 3/3 - 1s - 179ms/step - loss: 1.0155 - root_mean_squared_error: 1.0072 - val_loss: 1.3986 - val_root_mean_squared_error: 1.1822 - learning_rate: 1.0000e-03
# Epoch 54/500
# 3/3 - 1s - 172ms/step - loss: 1.0418 - root_mean_squared_error: 1.0202 - val_loss: 1.3993 - val_root_mean_squared_error: 1.1825 - learning_rate: 1.0000e-03
# Epoch 55/500
# 3/3 - 0s - 144ms/step - loss: 1.0363 - root_mean_squared_error: 1.0175 - val_loss: 1.3989 - val_root_mean_squared_error: 1.1823 - learning_rate: 1.0000e-03
# Epoch 56/500
# 3/3 - 1s - 237ms/step - loss: 1.0111 - root_mean_squared_error: 1.0050 - val_loss: 1.3998 - val_root_mean_squared_error: 1.1827 - learning_rate: 1.0000e-03
# Epoch 57/500
# 3/3 - 0s - 143ms/step - loss: 1.0637 - root_mean_squared_error: 1.0309 - val_loss: 1.3998 - val_root_mean_squared_error: 1.1827 - learning_rate: 1.0000e-03
# Epoch 58/500
# 3/3 - 0s - 117ms/step - loss: 1.0227 - root_mean_squared_error: 1.0108 - val_loss: 1.4002 - val_root_mean_squared_error: 1.1829 - learning_rate: 1.0000e-03
# Epoch 59/500
# 3/3 - 0s - 81ms/step - loss: 0.9997 - root_mean_squared_error: 0.9994 - val_loss: 1.3980 - val_root_mean_squared_error: 1.1820 - learning_rate: 1.0000e-03
# Epoch 60/500
# 3/3 - 0s - 105ms/step - loss: 1.0557 - root_mean_squared_error: 1.0270 - val_loss: 1.3944 - val_root_mean_squared_error: 1.1804 - learning_rate: 1.0000e-03
# Epoch 61/500
# 3/3 - 0s - 156ms/step - loss: 1.0724 - root_mean_squared_error: 1.0351 - val_loss: 1.3914 - val_root_mean_squared_error: 1.1792 - learning_rate: 1.0000e-03
# Epoch 62/500
# 3/3 - 0s - 91ms/step - loss: 1.0285 - root_mean_squared_error: 1.0137 - val_loss: 1.3881 - val_root_mean_squared_error: 1.1778 - learning_rate: 1.0000e-03
# Epoch 63/500
# 3/3 - 0s - 128ms/step - loss: 0.8833 - root_mean_squared_error: 0.9393 - val_loss: 1.3841 - val_root_mean_squared_error: 1.1761 - learning_rate: 1.0000e-03
# Epoch 64/500
# 3/3 - 0s - 88ms/step - loss: 1.0704 - root_mean_squared_error: 1.0341 - val_loss: 1.3816 - val_root_mean_squared_error: 1.1750 - learning_rate: 1.0000e-03
# Epoch 65/500
# 3/3 - 0s - 88ms/step - loss: 1.0449 - root_mean_squared_error: 1.0217 - val_loss: 1.3775 - val_root_mean_squared_error: 1.1733 - learning_rate: 1.0000e-03
# Epoch 66/500
# 3/3 - 1s - 201ms/step - loss: 1.0728 - root_mean_squared_error: 1.0353 - val_loss: 1.3747 - val_root_mean_squared_error: 1.1721 - learning_rate: 1.0000e-03
# Epoch 67/500
# 3/3 - 0s - 150ms/step - loss: 1.1200 - root_mean_squared_error: 1.0578 - val_loss: 1.3720 - val_root_mean_squared_error: 1.1709 - learning_rate: 1.0000e-03
# Epoch 68/500
# 3/3 - 1s - 201ms/step - loss: 0.9611 - root_mean_squared_error: 0.9798 - val_loss: 1.3705 - val_root_mean_squared_error: 1.1703 - learning_rate: 1.0000e-03
# Epoch 69/500
# 3/3 - 1s - 188ms/step - loss: 0.9721 - root_mean_squared_error: 0.9854 - val_loss: 1.3687 - val_root_mean_squared_error: 1.1695 - learning_rate: 1.0000e-03
# Epoch 70/500
# 3/3 - 1s - 201ms/step - loss: 1.0955 - root_mean_squared_error: 1.0462 - val_loss: 1.3664 - val_root_mean_squared_error: 1.1685 - learning_rate: 1.0000e-03
# Epoch 71/500
# 3/3 - 1s - 230ms/step - loss: 1.0260 - root_mean_squared_error: 1.0124 - val_loss: 1.3649 - val_root_mean_squared_error: 1.1679 - learning_rate: 1.0000e-03
# Epoch 72/500
# 3/3 - 1s - 214ms/step - loss: 1.0100 - root_mean_squared_error: 1.0045 - val_loss: 1.3675 - val_root_mean_squared_error: 1.1690 - learning_rate: 1.0000e-03
# Epoch 73/500
# 3/3 - 1s - 196ms/step - loss: 0.9794 - root_mean_squared_error: 0.9892 - val_loss: 1.3744 - val_root_mean_squared_error: 1.1719 - learning_rate: 1.0000e-03
# Epoch 74/500
# 3/3 - 0s - 132ms/step - loss: 1.0020 - root_mean_squared_error: 1.0005 - val_loss: 1.3819 - val_root_mean_squared_error: 1.1751 - learning_rate: 1.0000e-03
# Epoch 75/500
# 3/3 - 0s - 144ms/step - loss: 0.9624 - root_mean_squared_error: 0.9805 - val_loss: 1.3899 - val_root_mean_squared_error: 1.1785 - learning_rate: 1.0000e-03
# Epoch 76/500
# 3/3 - 1s - 195ms/step - loss: 0.9870 - root_mean_squared_error: 0.9930 - val_loss: 1.3953 - val_root_mean_squared_error: 1.1808 - learning_rate: 1.0000e-03
# Epoch 77/500
# 3/3 - 1s - 207ms/step - loss: 0.9972 - root_mean_squared_error: 0.9981 - val_loss: 1.4041 - val_root_mean_squared_error: 1.1845 - learning_rate: 1.0000e-03
# Epoch 78/500
# 3/3 - 0s - 137ms/step - loss: 0.8703 - root_mean_squared_error: 0.9324 - val_loss: 1.4145 - val_root_mean_squared_error: 1.1889 - learning_rate: 1.0000e-03
# Epoch 79/500
# 3/3 - 1s - 236ms/step - loss: 0.9915 - root_mean_squared_error: 0.9953 - val_loss: 1.4232 - val_root_mean_squared_error: 1.1926 - learning_rate: 1.0000e-03
# Epoch 80/500
# 3/3 - 1s - 401ms/step - loss: 1.0659 - root_mean_squared_error: 1.0319 - val_loss: 1.4250 - val_root_mean_squared_error: 1.1933 - learning_rate: 1.0000e-03
# Epoch 81/500
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 - 0s - 127ms/step - loss: 1.0545 - root_mean_squared_error: 1.0264 - val_loss: 1.4261 - val_root_mean_squared_error: 1.1938 - learning_rate: 1.0000e-03
# Epoch 82/500
# 3/3 - 1s - 189ms/step - loss: 1.0505 - root_mean_squared_error: 1.0244 - val_loss: 1.4261 - val_root_mean_squared_error: 1.1938 - learning_rate: 5.0000e-04
# Epoch 83/500
# 3/3 - 0s - 146ms/step - loss: 1.0451 - root_mean_squared_error: 1.0218 - val_loss: 1.4250 - val_root_mean_squared_error: 1.1933 - learning_rate: 5.0000e-04
# Epoch 84/500
# 3/3 - 0s - 100ms/step - loss: 1.0450 - root_mean_squared_error: 1.0218 - val_loss: 1.4204 - val_root_mean_squared_error: 1.1914 - learning_rate: 5.0000e-04
# Epoch 85/500
# 3/3 - 0s - 129ms/step - loss: 0.9520 - root_mean_squared_error: 0.9752 - val_loss: 1.4164 - val_root_mean_squared_error: 1.1897 - learning_rate: 5.0000e-04
# Epoch 86/500
# 3/3 - 0s - 109ms/step - loss: 0.9739 - root_mean_squared_error: 0.9864 - val_loss: 1.4150 - val_root_mean_squared_error: 1.1891 - learning_rate: 5.0000e-04
# Epoch 87/500
# 3/3 - 0s - 101ms/step - loss: 1.0712 - root_mean_squared_error: 1.0345 - val_loss: 1.4108 - val_root_mean_squared_error: 1.1874 - learning_rate: 5.0000e-04
# Epoch 88/500
# 3/3 - 0s - 125ms/step - loss: 0.9689 - root_mean_squared_error: 0.9838 - val_loss: 1.4084 - val_root_mean_squared_error: 1.1864 - learning_rate: 5.0000e-04
# Epoch 89/500
# 3/3 - 0s - 140ms/step - loss: 1.0369 - root_mean_squared_error: 1.0178 - val_loss: 1.4057 - val_root_mean_squared_error: 1.1852 - learning_rate: 5.0000e-04
# Epoch 90/500
# 3/3 - 0s - 132ms/step - loss: 0.9714 - root_mean_squared_error: 0.9851 - val_loss: 1.4042 - val_root_mean_squared_error: 1.1846 - learning_rate: 5.0000e-04
# Epoch 91/500
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 - 0s - 133ms/step - loss: 0.9452 - root_mean_squared_error: 0.9717 - val_loss: 1.4118 - val_root_mean_squared_error: 1.1878 - learning_rate: 5.0000e-04
# Epoch 92/500
# 3/3 - 0s - 120ms/step - loss: 1.0765 - root_mean_squared_error: 1.0371 - val_loss: 1.4160 - val_root_mean_squared_error: 1.1895 - learning_rate: 2.5000e-04
# Epoch 93/500
# 3/3 - 0s - 132ms/step - loss: 0.9003 - root_mean_squared_error: 0.9483 - val_loss: 1.4185 - val_root_mean_squared_error: 1.1906 - learning_rate: 2.5000e-04
# Epoch 94/500
# 3/3 - 0s - 110ms/step - loss: 0.9822 - root_mean_squared_error: 0.9906 - val_loss: 1.4210 - val_root_mean_squared_error: 1.1917 - learning_rate: 2.5000e-04
# Epoch 95/500
# 3/3 - 0s - 104ms/step - loss: 1.0390 - root_mean_squared_error: 1.0188 - val_loss: 1.4226 - val_root_mean_squared_error: 1.1923 - learning_rate: 2.5000e-04
# Epoch 96/500
# 3/3 - 0s - 90ms/step - loss: 0.9593 - root_mean_squared_error: 0.9789 - val_loss: 1.4239 - val_root_mean_squared_error: 1.1929 - learning_rate: 2.5000e-04
# Epoch 97/500
# 3/3 - 0s - 133ms/step - loss: 1.0689 - root_mean_squared_error: 1.0334 - val_loss: 1.4243 - val_root_mean_squared_error: 1.1930 - learning_rate: 2.5000e-04
# Epoch 98/500
# 3/3 - 1s - 189ms/step - loss: 1.0512 - root_mean_squared_error: 1.0248 - val_loss: 1.4236 - val_root_mean_squared_error: 1.1927 - learning_rate: 2.5000e-04
# Epoch 99/500
# 3/3 - 1s - 214ms/step - loss: 1.0612 - root_mean_squared_error: 1.0297 - val_loss: 1.4219 - val_root_mean_squared_error: 1.1920 - learning_rate: 2.5000e-04
# Epoch 100/500
# 3/3 - 1s - 210ms/step - loss: 1.0360 - root_mean_squared_error: 1.0174 - val_loss: 1.4206 - val_root_mean_squared_error: 1.1915 - learning_rate: 2.5000e-04
# Epoch 101/500
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3/3 - 1s - 183ms/step - loss: 0.9618 - root_mean_squared_error: 0.9802 - val_loss: 1.4201 - val_root_mean_squared_error: 1.1913 - learning_rate: 2.5000e-04

# %%
y_pred_s = model.predict(X_test)
y_pred   = scaler_y.inverse_transform(y_pred_s).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

eps = 1e-8
rel_err = np.abs((y_test - y_pred) / (np.where(np.abs(y_test) < eps, eps, y_test)))
pct_within_20 = np.mean(rel_err < 0.20) * 100

print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R2 Score: {r2:.4f}")
print(f"% within 20% error: {pct_within_20:.2f}%")
# Out:
# MSE: 0.1186
# RMSE: 0.3444
# MAE: 0.3346
# R2 Score: -0.1666
# % within 20% error: 100.00%

# %%
years_test = df_yearly['Year'].iloc[n_steps + train_size :].values  # indices that correspond to y_test
cmp_df = pd.DataFrame({
    'Year': years_test,
    'CPI_actual': y_test,
    'CPI_pred': y_pred
}).reset_index(drop=True)

print(cmp_df.head())

plt.figure(figsize=(10,5))
plt.plot(cmp_df['Year'], cmp_df['CPI_actual'], marker='o', linewidth=2, color='tab:blue', label='Actual CPI (test)')
plt.plot(cmp_df['Year'], cmp_df['CPI_pred'], marker='x', linewidth=2, color='tab:orange', label='Predicted CPI (test)')
plt.title('Actual vs Predicted CPI (test set)')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.grid(True)
plt.legend()
plt.xticks(cmp_df['Year'], rotation=45)
plt.tight_layout()
plt.show()
# Out:
#    Year  CPI_actual  CPI_pred
# 0  2021    5.323190  5.016524
# 1  2022    4.764910  5.016524
# 2  2023    4.570992  5.016524

# %%
import os
import joblib

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
models_folder = os.path.join(project_root, 'models')
os.makedirs(models_folder, exist_ok=True)
model_path = os.path.join(models_folder, 'gru_model.h5')

# %%
model.save(model_path)
print(f"GRU model saved at: {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# GRU model saved at: c:\Web development\GRU-RNN_InflationModel\models\gru_model.h5

# %%
scaler = StandardScaler()

scaler_path = os.path.join(models_folder, 'scaler.save')
joblib.dump(scaler, scaler_path)
print(f"Scaler saved at: {scaler_path}")
# Out:
# Scaler saved at: c:\Web development\GRU-RNN_InflationModel\models\scaler.save
